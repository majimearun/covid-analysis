# %%
import pandas as pd

# %%
df = pd.read_csv('continents.csv')
df.head()
# Out:
#        continent        lat        long  confirmed_cumulative  confirmed_new  \
# 0  North America  31.676827 -146.470747              48842117          18731
# 1           Asia  23.702727   62.375064              70928962          52786
# 2  South America -15.655156 -100.748423              37032591              0
# 3         Europe  25.771324  -35.601226              55757610           6789
# 4         Africa   1.738387  -16.309464               7945176              0
#
#    deaths_cumulative  deaths_new  recovered_cumulative  recovered_new  \
# 0            1006673         758              38074046          17261
# 1            1047701         677              66187672          67529
# 2            1134070           0              34851630              0
# 3            1178282          57              50876944          10086
# 4             198801           0               7074996              0
#
#     active  critical        updated
# 0  9761398     33013  1630743097271
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df = pd.read_csv('countries.csv')
df.head()
# Out:
#        country   lat  long  confirmed_cumulative  confirmed_new  \
# 0  Afghanistan  33.0  65.0                153395              0
# 1      Albania  41.0  20.0                149117              0
# 2      Algeria  28.0   3.0                197308              0
# 3      Andorra  42.5   1.6                 15055              0
# 4       Angola -12.5  18.5                 48261              0
#
#    deaths_cumulative  deaths_new  recovered_cumulative  recovered_new  active  \
# 0               7128           0                111300              0   34967
# 1               2508           0                135321              0   11288
# 2               5373           0                134390              0   57545
# 3                130           0                 14874              0      51
# 4               1248           0                 43795              0    3218
#
#    critical        updated continent  \
# 0      1124  1630743096778      Asia
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=223, step=1)

# %%
df = pd.read_csv('vac_country.csv')
df.head()
# Out:
#     Unnamed: 0  12/1/20  12/2/20  12/3/20  12/4/20  12/5/20  12/6/20  12/7/20  \
# 0  Afghanistan        0        0        0        0        0        0        0
# 1      Albania        0        0        0        0        0        0        0
# 2      Algeria        0        0        0        0        0        0        0
# 3      Andorra        0        0        0        0        0        0        0
# 4       Angola        0        0        0        0        0        0        0
#
#    12/8/20  12/9/20  ...  8/25/21  8/26/21  8/27/21  8/28/21  8/29/21  \
# 0        0        0  ...  1356114  1416926  1487687  1558448  1629209
# 1        0        0  ...  1405653  1415907  1427977  1436980  1444764
# 2        0        0  ...  4146091  4146091  4146091  4146091  4146091
# 3        0        0  ...    91660    91660    91660    91660    91660
# 4        0        0  ...  1841568  1860012  1882501  1907486  1934966
#
#    8/30/21  8/31/21   9/1/21   9/2/21   9/3/21
# ...
